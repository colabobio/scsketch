# %%
import scsketch, importlib
print("version:", getattr(scsketch, "__version__", "unknown"))
print("file:", scsketch.__file__)
print("has view:", hasattr(scsketch, "view"))
# Out:
# version: 0.0.2
# file: /Users/askartemirbek/anywidgets_practice/scsketch/src/scsketch/__init__.py
# has view: True

# %%
import sys
sys.executable
# Out:
# '/opt/homebrew/Caskroom/miniforge/base/envs/scsketch091525/bin/python3.13'

# %%
importlib.metadata.distribution("scsketch").locate_file("")
# Out:
# PosixPath('/opt/homebrew/Caskroom/miniforge/base/envs/scsketch091525/lib/python3.13/site-packages')

# %%
# !python -m pip show scsketch
# Out:
# /Users/askartemirbek/.local/share/uv/tools/juv/bin/python: No module named pip

# %%
import sys
# !{sys.executable} -m pip --version
# !{sys.executable} -m pip show scsketch
# Out:
# pip 25.2 from /opt/homebrew/Caskroom/miniforge/base/envs/scsketch091525/lib/python3.13/site-packages/pip (python 3.13)
# Name: scsketch
# Version: 0.0.2
# Summary:
# Home-page:
# Author:
# Author-email:
# License:
# Location: /opt/homebrew/Caskroom/miniforge/base/envs/scsketch091525/lib/python3.13/site-packages
# Editable project location: /Users/askartemirbek/anywidgets_practice/scsketch
# Requires: anywidget, jupyter-scatter, matplotlib, numpy, pandas, requests, scanpy, umap-learn
# Required-by:

# %%
# !{sys.executable} -c "import tomllib, pathlib; print(tomllib.loads(pathlib.Path('pyproject.toml').read_text())['project']['version'])"
# Out:
# 0.0.3

# %%
# !{sys.executable} -m pip install -e .
# Out:
# Obtaining file:///Users/askartemirbek/anywidgets_practice/scsketch
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for scsketch (pyproject.toml) ... done
#   Created wheel for scsketch: filename=scsketch-0.0.3-py3-none-any.whl size=2387 sha256=abf320ccd4754fc81868e7e6622289a20047e2f6b6383a786756ce76b3fcb898
#   Stored in directory: /private/var/folders/1q/lrn2j95x1g99g76hldp41gxr0000gp/T/pip-ephem-wheel-cache-znn2bzm0/wheels/e4/e6/c1/0681d884453a3b1e5d25eedcdaeaa8037631b3da52fdf378af
# Successfully built scsketch
# ...
#   Attempting uninstall: scsketch
#     Found existing installation: scsketch 0.0.2
#     Uninstalling scsketch-0.0.2:
#       Successfully uninstalled scsketch-0.0.2
# ...

# %%
import scsketch
print(scsketch.__version__)
# Out:
# 0.0.2
